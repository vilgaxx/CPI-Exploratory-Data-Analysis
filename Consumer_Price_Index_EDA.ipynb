# %% [markdown]
# <a href="https://colab.research.google.com/github/vilgaxx/CPI-Exploratory-Data-Analysis/blob/main/Consumer_Price_Index_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Importing the required libraries for EDA**

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline
sns.set(color_codes=True)

# %% [markdown]
# **2. Loading the data into the data frame.**

# %%
df = pd.read_csv("datafile.csv")
# To display the top 5 rows
df.head(5)
# Out:
#         Sector  Year      Name  Andhra Pradesh  Arunachal Pradesh  Assam  \
# 0        Rural  2011   January           104.0                NaN  104.0
# 1        Urban  2011   January           103.0                NaN  103.0
# 2  Rural+Urban  2011   January           103.0                NaN  104.0
# 3        Rural  2011  February           107.0                NaN  105.0
# 4        Urban  2011  February           106.0                NaN  106.0
#
#    Bihar  Chattisgarh  Delhi    Goa  ...  Uttar Pradesh  Uttarakhand  \
# 0    NaN        105.0    NaN  103.0  ...          103.0          NaN
# 1    NaN        104.0    NaN  103.0  ...          103.0          NaN
# 2    NaN        104.0    NaN  103.0  ...          103.0          NaN
# 3    NaN        107.0    NaN  105.0  ...          104.0          NaN
# 4    NaN        106.0    NaN  105.0  ...          105.0          NaN
#
#   West Bengal  Andaman and Nicobar  Chandigarh  Dadra and Nagar Haveli  \
# ...

# %%
df.tail(5)                        # To display the botton 5 rows
# Out:
#           Sector  Year   Name  Andhra Pradesh  Arunachal Pradesh  Assam  \
# 438        Rural  2023  April           181.5              183.1  179.5
# 439        Urban  2023  April             NaN                NaN  177.2
# 440  Rural+Urban  2023  April           182.6              183.1  179.0
# 441        Rural  2023    May           183.1              183.8  181.0
# 442        Urban  2023    May           185.5                NaN  179.2
#
#      Bihar  Chattisgarh  Delhi    Goa  ...  Uttar Pradesh  Uttarakhand  \
# 438  172.7        168.7  166.1  173.7  ...          176.5        175.9
# 439  180.1        167.6  165.6  170.2  ...          178.2        179.2
# 440  173.8        168.3  165.6  171.6  ...          177.1        177.1
# 441  173.9        169.9  166.9  172.7  ...          177.1        176.6
# 442  181.7        168.4  165.5  171.4  ...          178.8        181.2
#
#     West Bengal  Andaman and Nicobar  Chandigarh  Dadra and Nagar Haveli  \
# ...

# %% [markdown]
# **3. Checking the types of data**

# %%
df.dtypes
# Out:
# Sector                     object
# Year                        int64
# Name                       object
# Andhra Pradesh            float64
# Arunachal Pradesh         float64
# Assam                     float64
# Bihar                     float64
# Chattisgarh               float64
# Delhi                     float64
# Goa                       float64
# Gujarat                   float64
# Haryana                   float64
# Himachal Pradesh           object
# Jharkhand                 float64
# Karnataka                 float64
# Kerala                    float64
# Madhya Pradesh            float64
# Maharashtra               float64
# Manipur                   float64
# Meghalaya                 float64
# Mizoram                   float64
# Nagaland                  float64
# Orissa                    float64
# Punjab                    float64
# Rajasthan                 float64
# Sikkim                    float64
# Tamil Nadu                float64
# ...

# %% [markdown]
# **4. Dropping irrelevant columns**

# %%
df = df.drop(['Arunachal Pradesh', 'Bihar', 'Delhi', 'Nagaland', 'Rajasthan', 'Sikkim','Telangana','Uttarakhand'], axis=1)
df.head(5)
# Out:
#         Sector  Year      Name  Andhra Pradesh  Assam  Chattisgarh    Goa  \
# 0        Rural  2011   January           104.0  104.0        105.0  103.0
# 1        Urban  2011   January           103.0  103.0        104.0  103.0
# 2  Rural+Urban  2011   January           103.0  104.0        104.0  103.0
# 3        Rural  2011  February           107.0  105.0        107.0  105.0
# 4        Urban  2011  February           106.0  106.0        106.0  105.0
#
#    Gujarat  Haryana Himachal Pradesh  ...  Tripura  Uttar Pradesh  \
# 0    104.0    104.0              104  ...    105.0          103.0
# 1    104.0    104.0              103  ...    105.0          103.0
# 2    104.0    104.0              103  ...    105.0          103.0
# 3    106.0    106.0              105  ...    107.0          104.0
# 4    107.0    107.0              105  ...    108.0          105.0
#
#    West Bengal  Andaman and Nicobar  Chandigarh  Dadra and Nagar Haveli  \
# ...

# %% [markdown]
# **6. Dropping the duplicate rows**

# %%
df.shape
# Out:
# (443, 31)

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 31)

# %%
df.count()
# Out:
# Sector                    443
# Year                      443
# Name                      443
# Andhra Pradesh            433
# Assam                     434
# Chattisgarh               434
# Goa                       434
# Gujarat                   434
# Haryana                   434
# Himachal Pradesh          428
# Jharkhand                 434
# Karnataka                 434
# Kerala                    434
# Madhya Pradesh            434
# Maharashtra               434
# Manipur                   434
# Meghalaya                 434
# Mizoram                   434
# Orissa                    434
# Punjab                    434
# Tamil Nadu                434
# Tripura                   428
# Uttar Pradesh             434
# West Bengal               428
# Andaman and Nicobar       434
# Chandigarh                434
# Dadra and Nagar Haveli    434
# Daman and Diu             434
# Jammu and Kashmir         434
# Lakshadweep               434
# Puducherry                434
# ...

# %% [markdown]
# **7. Dropping the missing or null values.**

# %%
print(df.isnull().sum())
# Out:
# Sector                     0
# Year                       0
# Name                       0
# Andhra Pradesh            10
# Assam                      9
# Chattisgarh                9
# Goa                        9
# Gujarat                    9
# Haryana                    9
# Himachal Pradesh          15
# Jharkhand                  9
# Karnataka                  9
# Kerala                     9
# Madhya Pradesh             9
# Maharashtra                9
# Manipur                    9
# Meghalaya                  9
# Mizoram                    9
# Orissa                     9
# Punjab                     9
# Tamil Nadu                 9
# Tripura                   15
# Uttar Pradesh              9
# West Bengal               15
# Andaman and Nicobar        9
# Chandigarh                 9
# Dadra and Nagar Haveli     9
# Daman and Diu              9
# Jammu and Kashmir          9
# Lakshadweep                9
# Puducherry                 9
# dtype: int64

# %%
df = df.dropna()    # Dropping the missing values.
df.count()
# Out:
# Sector                    423
# Year                      423
# Name                      423
# Andhra Pradesh            423
# Assam                     423
# Chattisgarh               423
# Goa                       423
# Gujarat                   423
# Haryana                   423
# Himachal Pradesh          423
# Jharkhand                 423
# Karnataka                 423
# Kerala                    423
# Madhya Pradesh            423
# Maharashtra               423
# Manipur                   423
# Meghalaya                 423
# Mizoram                   423
# Orissa                    423
# Punjab                    423
# Tamil Nadu                423
# Tripura                   423
# Uttar Pradesh             423
# West Bengal               423
# Andaman and Nicobar       423
# Chandigarh                423
# Dadra and Nagar Haveli    423
# Daman and Diu             423
# Jammu and Kashmir         423
# Lakshadweep               423
# Puducherry                423
# ...

# %%
print(df.isnull().sum())   # After dropping the values
# Out:
# Sector                    0
# Year                      0
# Name                      0
# Andhra Pradesh            0
# Assam                     0
# Chattisgarh               0
# Goa                       0
# Gujarat                   0
# Haryana                   0
# Himachal Pradesh          0
# Jharkhand                 0
# Karnataka                 0
# Kerala                    0
# Madhya Pradesh            0
# Maharashtra               0
# Manipur                   0
# Meghalaya                 0
# Mizoram                   0
# Orissa                    0
# Punjab                    0
# Tamil Nadu                0
# Tripura                   0
# Uttar Pradesh             0
# West Bengal               0
# Andaman and Nicobar       0
# Chandigarh                0
# Dadra and Nagar Haveli    0
# Daman and Diu             0
# Jammu and Kashmir         0
# Lakshadweep               0
# Puducherry                0
# dtype: int64

# %% [markdown]
# **Heat Maps**

# %%
plt.figure(figsize=(30,15))
c= df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
# <ipython-input-14-1bfbf02fa95a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= df.corr()
#                             Year  Andhra Pradesh     Assam  Chattisgarh  \
# Year                    1.000000        0.888202  0.891644     0.874516
# Andhra Pradesh          0.888202        1.000000  0.983631     0.985080
# Assam                   0.891644        0.983631  1.000000     0.977594
# Chattisgarh             0.874516        0.985080  0.977594     1.000000
# Goa                     0.889278        0.963017  0.958863     0.978392
# Gujarat                 0.867746        0.975116  0.979001     0.981980
# Haryana                 0.881857        0.989750  0.992074     0.983313
# Jharkhand               0.891997        0.983634  0.985744     0.986558
# ...

# %% [markdown]
# **Scatterplot**

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df['Maharashtra'], df['Goa'])
ax.set_xlabel('Maharashtra')
ax.set_ylabel('Goa')
plt.show()

# %% [markdown]
# **Performed normalization of the entire raw data and display its 11th row from the top before and after normalization.**

# %%
from sklearn.preprocessing import MinMaxScaler

# Display the 11th row from the top before normalization
row_11_before = df.iloc[10]

scaler = MinMaxScaler()

# Apply Min-Max scaling to the entire DataFrame
normalized_data = scaler.fit_transform(df.select_dtypes(include=['float64']))

# Create a new DataFrame with the normalized data
normalized_df = pd.DataFrame(normalized_data, columns=df.select_dtypes(include=['float64']).columns)

# Add the non-numeric columns back to the normalized DataFrame
for col in df.columns:
    if col not in normalized_df.columns:
        normalized_df[col] = df[col]

# Display the 11th row from the top after normalization
row_11_after = normalized_df.iloc[10]


print("11th Row from the top before normalization:")
print(row_11_before)

print("\n11th Row from the top after normalization:")
print(row_11_after)
# Out:
# 11th Row from the top before normalization:
# Sector                    Urban
# Year                       2011
# Name                      April
# Andhra Pradesh            104.9
# Assam                     107.1
# Chattisgarh               105.4
# Goa                       105.4
# Gujarat                   107.1
# Haryana                   107.3
# Himachal Pradesh            105
# Jharkhand                 106.8
# Karnataka                 107.0
# Kerala                    108.8
# Madhya Pradesh            106.1
# Maharashtra               106.0
# Manipur                   102.7
# Meghalaya                 111.1
# Mizoram                   108.3
# Orissa                    106.8
# Punjab                    104.9
# Tamil Nadu                105.5
# Tripura                   107.8
# Uttar Pradesh             104.2
# West Bengal               107.7
# Andaman and Nicobar       105.1
# Chandigarh                103.9
# Dadra and Nagar Haveli    105.8
# Daman and Diu             104.7
# ...

# %% [markdown]
# **Perform standardization over the entire raw data and display its 10th row before and after standardization.**

# %%
from sklearn.preprocessing import StandardScaler

# Display the 10th row from the top before standardization
row_10_before = df.iloc[9]  # Note that index 9 corresponds to the 10th row, as indexing starts from 0.

# Create a StandardScaler
scaler = StandardScaler()

# Apply standardization to the entire DataFrame
standardized_data = scaler.fit_transform(df.select_dtypes(include=['float64']))

# Create a new DataFrame with the standardized data
standardized_df = pd.DataFrame(standardized_data, columns=df.select_dtypes(include=['float64']).columns)

# Add the non-numeric columns back to the standardized DataFrame
for col in df.columns:
    if col not in standardized_df.columns:
        standardized_df[col] = df[col]

# Display the 10th row from the top after standardization
row_10_after = standardized_df.iloc[9]

# Print the results
print("10th Row from the top before standardization:")
print(row_10_before)

print("\n10th Row from the top after standardization:")
print(row_10_after)
# Out:
# 10th Row from the top before standardization:
# Sector                    Rural
# Year                       2011
# Name                      April
# Andhra Pradesh            105.0
# Assam                     106.0
# Chattisgarh               105.0
# Goa                       104.0
# Gujarat                   106.0
# Haryana                   106.0
# Himachal Pradesh            104
# Jharkhand                 106.0
# Karnataka                 106.0
# Kerala                    108.0
# Madhya Pradesh            106.0
# Maharashtra               105.0
# Manipur                   103.0
# Meghalaya                 111.0
# Mizoram                   107.0
# Orissa                    106.0
# Punjab                    104.0
# Tamil Nadu                105.0
# Tripura                   107.0
# Uttar Pradesh             103.0
# West Bengal               107.0
# Andaman and Nicobar       104.0
# Chandigarh                103.0
# Dadra and Nagar Haveli    105.0
# Daman and Diu             104.0
# ...

# %% [markdown]
# **Thank You !**
